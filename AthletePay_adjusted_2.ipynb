# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %%
# The path to our CSV file
athleteInfo = Path("Resources/ForbesInfo.csv")

athlete_df = pd.read_csv(athleteInfo)
athlete_df.head()
# Out:
#    S.NO               Name Nationality  Current Rank Previous Year Rank  \
# 0     1         Mike Tyson         USA             1                NaN
# 1     2     Buster Douglas         USA             2                NaN
# 2     3  Sugar Ray Leonard         USA             3                NaN
# 3     4       Ayrton Senna      Brazil             4                NaN
# 4     5        Alain Prost      France             5                NaN
#
#          Sport  Year  earnings ($ million)
# 0       boxing  1990                  28.6
# 1       boxing  1990                  26.0
# 2       boxing  1990                  13.0
# 3  auto racing  1990                  10.0
# 4  auto racing  1990                   9.0

# %%
athlete_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   S.NO                  301 non-null    int64
#  1   Name                  301 non-null    object
#  2   Nationality           301 non-null    object
#  3   Current Rank          301 non-null    int64
#  4   Previous Year Rank    277 non-null    object
#  5   Sport                 301 non-null    object
#  6   Year                  301 non-null    int64
#  7   earnings ($ million)  301 non-null    float64
# dtypes: float64(1), int64(3), object(4)
# memory usage: 18.9+ KB

# %%
athlete_df.columns
# Out:
# Index(['S.NO', 'Name', 'Nationality', 'Current Rank', 'Previous Year Rank',
#        'Sport', 'Year', 'earnings ($ million)'],
#       dtype='object')

# %%
athlete_df = athlete_df.set_index("S.NO")
athlete_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 301 entries, 1 to 301
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Name                  301 non-null    object
#  1   Nationality           301 non-null    object
#  2   Current Rank          301 non-null    int64
#  3   Previous Year Rank    277 non-null    object
#  4   Sport                 301 non-null    object
#  5   Year                  301 non-null    int64
#  6   earnings ($ million)  301 non-null    float64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 18.8+ KB

# %%
athlete_df.Sport.value_counts()
# Out:
# Sport
# Basketball                      54
# Boxing                          29
# basketball                      27
# Golf                            24
# Soccer                          22
# golf                            20
# Tennis                          18
# boxing                          17
# American Football               17
# soccer                          11
# Auto Racing                     10
# F1 racing                        8
# auto racing                      7
# tennis                           5
# F1 Motorsports                   5
# motorcycle gp                    4
# NFL                              3
# Baseball                         3
# NASCAR                           3
# baseball                         3
# Ice Hockey                       2
# Auto Racing (Nascar)             2
# cycling                          1
# American Football / Baseball     1
# Hockey                           1
# ice hockey                       1
# ...

# %%
# Count hoy many entries there are per sport
sportCount = athlete_df.groupby("Sport").Sport.count().sort_values(ascending = False)
sportCount
# Out:
# Sport
# Basketball                      54
# Boxing                          29
# basketball                      27
# Golf                            24
# Soccer                          22
# golf                            20
# Tennis                          18
# American Football               17
# boxing                          17
# soccer                          11
# Auto Racing                     10
# F1 racing                        8
# auto racing                      7
# tennis                           5
# F1 Motorsports                   5
# motorcycle gp                    4
# NFL                              3
# baseball                         3
# Baseball                         3
# NASCAR                           3
# Ice Hockey                       2
# Auto Racing (Nascar)             2
# American Football / Baseball     1
# NBA                              1
# MMA                              1
# Hockey                           1
# ...

# %%
athlete_df.loc[athlete_df.Sport=="basketball", "Sport"] = "Basketball"
athlete_df.loc[athlete_df.Sport=="boxing", "Sport"] = "Boxing"
athlete_df.loc[athlete_df.Sport=="golf", "Sport"] = "Golf"
athlete_df.loc[athlete_df.Sport=="soccer", "Sport"] = "Soccer"
athlete_df.loc[athlete_df.Sport=="ice hockey", "Sport"] = "Ice Hockey"
athlete_df.loc[athlete_df.Sport=="hockey", "Sport"] = "Ice Hockey"
athlete_df.loc[athlete_df.Sport=="Hockey", "Sport"] = "Ice Hockey"
athlete_df.loc[athlete_df.Sport=="American Football / Baseball", "Sport"] = "American Football"
athlete_df.loc[athlete_df.Sport=="NFL", "Sport"] = "American Football" 
athlete_df.loc[athlete_df.Sport=="baseball", "Sport"] = "Baseball"
athlete_df.loc[athlete_df.Sport=="tennis", "Sport"] = "Tennis"
athlete_df.loc[athlete_df.Sport=="NBA", "Sport"] = "Basketball"
athlete_df.loc[(athlete_df.Sport=="F1 racing")| (athlete_df.Sport== "Auto racing") | (athlete_df.Sport== "auto racing") | (athlete_df.Sport== "Auto Racing") , "Sport"] = "F1 Motorsports"
athlete_df.loc[athlete_df.Sport=="cycling", "Sport"] = "Cycling"
athlete_df.loc[athlete_df.Sport=="NBA", "Sport"] = "Basketball"
athlete_df.loc[athlete_df.Sport=="F1 racing", "Sport"] = "F1 Motorsports"
athlete_df.loc[athlete_df.Sport=="cycling", "Sport"] = "Cycling"
athlete_df.loc[athlete_df.Sport=="tennis", "Sport"] = "Tennis"
athlete_df.loc[athlete_df.Sport=="Hockey", "Sport"] = "Ice Hockey"
athlete_df.loc[athlete_df.Sport=="American Football / Baseball", "Sport"] = "American Football"
athlete_df.loc[athlete_df.Sport=="NFL", "Sport"] = "American Football" 
athlete_df.loc[athlete_df.Sport=="ice hockey", "Sport"] = "Ice Hockey"
athlete_df.loc[athlete_df.Sport=="baseball", "Sport"] = "Baseball"
athlete_df.loc[athlete_df.Sport=="soccer", "Sport"] = "Soccer"
athlete_df.loc[(athlete_df.Sport== "NASCAR")|(athlete_df.Sport== "Auto Racing (Nascar)"), "Sport"] = "NASCAR"
athlete_df.loc[athlete_df.Sport=="motorcycle gp", "Sport"] = "Motorcycle GP"

athlete_df.to_csv("Trial")
athlete_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 301 entries, 1 to 301
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Name                  301 non-null    object
#  1   Nationality           301 non-null    object
#  2   Current Rank          301 non-null    int64
#  3   Previous Year Rank    277 non-null    object
#  4   Sport                 301 non-null    object
#  5   Year                  301 non-null    int64
#  6   earnings ($ million)  301 non-null    float64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 18.8+ KB

# %%
athlete_df.loc[(athlete_df.Nationality== "Philippines") |(athlete_df.Nationality== "Filipino"), "Nationality"] = "Philippines"

# %%
athlete_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 301 entries, 1 to 301
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Name                  301 non-null    object
#  1   Nationality           301 non-null    object
#  2   Current Rank          301 non-null    int64
#  3   Previous Year Rank    277 non-null    object
#  4   Sport                 301 non-null    object
#  5   Year                  301 non-null    int64
#  6   earnings ($ million)  301 non-null    float64
# dtypes: float64(1), int64(2), object(4)
# memory usage: 18.8+ KB

# %%
inflation_data = Path("Resources/uscpi.csv")

inflation_df = pd.read_csv(inflation_data)
inflation_df.head()
# Out:
#       Yearmon  CPI
# 0  01-01-1913  9.8
# 1  01-02-1913  9.8
# 2  01-03-1913  9.8
# 3  01-04-1913  9.8
# 4  01-05-1913  9.7

# %%
inflation_df[['Day','Month', 'Year']] = inflation_df['Yearmon'].str.split('-',expand=True)
inflation_df["Year"] = inflation_df.Year.astype("int64")

# %%
inflation_year = inflation_df.groupby('Year').CPI.mean().reset_index()

# %%
inflation_year
# Out:
#      Year         CPI
# 0    1913    9.883333
# 1    1914   10.016667
# 2    1915   10.108333
# 3    1916   10.883333
# 4    1917   12.825000
# ..    ...         ...
# 104  2017  245.119583
# 105  2018  251.106833
# 106  2019  255.657417
# 107  2020  258.811167
# 108  2021  267.203000
#
# [109 rows x 2 columns]

# %%
inflation_year.columns
# Out:
# Index(['Year', 'CPI'], dtype='object')

# %%
# Add inflation column and calculate inflation with 1990 as base year
# inflation_year["inflation"] = np.nan

base = inflation_year.loc[inflation_year.Year == 1990, "CPI"].values[0]
base
inflation_year["inflation"] = inflation_year.CPI.apply(lambda row : ((row - base)/base))

inflation_year
# Out:
#      Year         CPI  inflation
# 0    1913    9.883333  -0.924357
# 1    1914   10.016667  -0.923337
# 2    1915   10.108333  -0.922635
# 3    1916   10.883333  -0.916704
# 4    1917   12.825000  -0.901843
# ..    ...         ...        ...
# 104  2017  245.119583   0.876035
# 105  2018  251.106833   0.921859
# 106  2019  255.657417   0.956687
# 107  2020  258.811167   0.980824
# 108  2021  267.203000   1.045051
#
# [109 rows x 3 columns]

# %%
sub_inflation_df = inflation_year.loc[inflation_year.Year >= 1990]
sub_inflation_df.head()
sub_inflation_df.dtypes
# Out:
# Year           int64
# CPI          float64
# inflation    float64
# dtype: object

# %%
adjusted_df = pd.merge(athlete_df, sub_inflation_df.loc[:, ["Year", "inflation"]], on = "Year", how = "left")
adjusted_df
# Out:
#                   Name Nationality  Current Rank Previous Year Rank  \
# 0           Mike Tyson         USA             1                NaN
# 1       Buster Douglas         USA             2                NaN
# 2    Sugar Ray Leonard         USA             3                NaN
# 3         Ayrton Senna      Brazil             4                NaN
# 4          Alain Prost      France             5                NaN
# ..                 ...         ...           ...                ...
# 296      Stephen Curry         USA             6                  9
# 297       Kevin Durant         USA             7                 10
# 298        Tiger Woods         USA             8                 11
# 299       Kirk Cousins         USA             9               >100
# 300       Carson Wentz         USA            10               >100
#
#                  Sport  Year  earnings ($ million)  inflation
# 0               Boxing  1990                  28.6   0.000000
# ...

# %%
adjusted_df["Adjusted_Earnings"] = adjusted_df["earnings ($ million)"] / (1 + adjusted_df.inflation)
adjusted_df
# Out:
#                   Name Nationality  Current Rank Previous Year Rank  \
# 0           Mike Tyson         USA             1                NaN
# 1       Buster Douglas         USA             2                NaN
# 2    Sugar Ray Leonard         USA             3                NaN
# 3         Ayrton Senna      Brazil             4                NaN
# 4          Alain Prost      France             5                NaN
# ..                 ...         ...           ...                ...
# 296      Stephen Curry         USA             6                  9
# 297       Kevin Durant         USA             7                 10
# 298        Tiger Woods         USA             8                 11
# 299       Kirk Cousins         USA             9               >100
# 300       Carson Wentz         USA            10               >100
#
#                  Sport  Year  earnings ($ million)  inflation  \
# 0               Boxing  1990                  28.6   0.000000
# ...

# %%
import matplotlib.pyplot as plt
from scipy.stats import linregress

# Define a function to create Linear Regression plots
def linear_regression_plot(x_values,y_values,x_label,y_label,annot_loc,fig_name):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    COLOR = '#F8F3E4'
    dark_color = '#001219'

    plt.rcParams['text.color'] = COLOR
    plt.rcParams['axes.labelcolor'] = COLOR
    plt.rcParams['xtick.color'] = COLOR
    plt.rcParams['ytick.color'] = COLOR
    plt.rcParams['axes.edgecolor'] = COLOR
    plt.rcParams['savefig.transparent'] = True
    plt.rcParams['legend.labelcolor'] = dark_color
    plt.rcParams['legend.framealpha'] = 1
    
    # make plot
    plt.figure(figsize = (15,10))
    plt.scatter(x_values,y_values, color = "#94d2bd")
    plt.plot(x_values,regress_values, color = "#ee9b00")
    plt.annotate(line_eq, annot_loc, fontsize=12, color= "#ee9b00")
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(f'{x_label} vs {y_label}', fontweight = "bold", fontsize = 13)
    print(f"The r-squared is: {rvalue**2}")
    plt.savefig(fig_name)
    plt.show()

x_label = "Years"
y_label = "Adjusted Earnings (US$ MM)"
fig_name = "Scatter with outliers"

linear_regression_plot(adjusted_df.Year.astype(float), adjusted_df.Adjusted_Earnings.astype(float), x_label, y_label,(2015,10), fig_name)
adjusted_df.count()

# colors = ['#005f73', '#0a9396', '#ee9b00', '#94d2bd', '#ae2012', '#9b2226']
# plt.figure(figsize = (15,10))
# plt.scatter(adjusted_df.Year, adjusted_df.Adjusted_Earnings, color = '#ee9b00', s = 80)
# plt.title("Ajusted Earnings through the Years", fontweight='bold', fontname = "Calibri", fontsize = 20)
# plt.xlabel("Years", fontname = "Calibri", fontsize = 16, fontweight = "bold")
# plt.ylabel("Ajusted Earnings (US$ MM)", fontname = "Calibri", fontsize = 16, fontweight = "bold")
# Out:
# The r-squared is: 0.25234927789082784
# Name                    301
# Nationality             301
# Current Rank            301
# Previous Year Rank      277
# Sport                   301
# Year                    301
# earnings ($ million)    301
# inflation               301
# Adjusted_Earnings       301
# dtype: int64

# %%
df_99 = adjusted_df['Adjusted_Earnings'].astype(float).quantile(0.99)
outliers_df = adjusted_df.loc[adjusted_df['Adjusted_Earnings'] <= df_99]
outliers_df.head()

x_label = "Years"
y_label = "Adjusted Earnings (US$ MM)"
fig_name = "Scatter without outliers"

linear_regression_plot(outliers_df.Year.astype(float), outliers_df.Adjusted_Earnings.astype(float), x_label, y_label,(2015,10), fig_name)
outliers_df.count()
# Out:
# The r-squared is: 0.3125378166522069
# Name                    298
# Nationality             298
# Current Rank            298
# Previous Year Rank      274
# Sport                   298
# Year                    298
# earnings ($ million)    298
# inflation               298
# Adjusted_Earnings       298
# dtype: int64

# %%
outliers2 = outliers_df.loc[outliers_df['Current Rank'] > 1]

x_label = "Years"
y_label = "Adjusted Earnings (US$ MM)"
fig_name = "Scatter without outliers 2"

linear_regression_plot(outliers2.Year.astype(float), outliers2.Adjusted_Earnings.astype(float), x_label, y_label,(2015,10), fig_name)
# Out:
# The r-squared is: 0.5193009133345289

# %%
adjusted_df.sort_values(by = "Adjusted_Earnings", ascending = False)
# Out:
#                   Name  Nationality  Current Rank Previous Year Rank  \
# 241   Floyd Mayweather          USA             1                  1
# 271   Floyd Mayweather          USA             1               >100
# 242     Manny Pacquiao  Philippines             2                 11
# 171        Tiger Woods          USA             1                  1
# 181        Tiger Woods          USA             1                  1
# ..                 ...          ...           ...                ...
# 19   Sugar Ray Leonard          USA            10                  6
# 9    Evander Holyfield          USA             8                NaN
# 8        Arnold Palmer          USA             8                NaN
# 7       Michael Jordan          USA             8                NaN
# 29        Monica Seles          USA            10                 12
#
#           Sport  Year  earnings ($ million)  inflation  Adjusted_Earnings
# ...

# %%
adjusted_df.loc[adjusted_df.Name == "Manny Pacquiao"].sort_values(by = "Year")
# Out:
#                Name  Nationality  Current Rank Previous Year Rank   Sport  \
# 188  Manny Pacquiao  Philippines             6                >10  Boxing
# 198  Manny Pacquiao  Philippines             8                  6  Boxing
# 212  Manny Pacquiao  Philippines             2                 24  Boxing
# 242  Manny Pacquiao  Philippines             2                 11  Boxing
#
#      Year  earnings ($ million)  inflation  Adjusted_Earnings
# 188  2009                  40.0   0.641970          24.360988
# 198  2010                  42.0   0.668899          25.166299
# 212  2012                  62.0   0.757208          35.283237
# 242  2015                 160.0   0.814021          88.201831

# %%
# Create pie charts to compare counts by nationality and agregated earnings by nationality
nationalities = adjusted_df.groupby("Nationality").Adjusted_Earnings.sum().sort_values(ascending = False).reset_index()
temp = adjusted_df.Nationality.value_counts().reset_index()
nationalities = pd.merge(nationalities.loc[:,["Nationality", "Adjusted_Earnings"]], temp.loc[:,["Nationality", "count"]], on = "Nationality")
nationalities


 

#plt.pie(sizes, colors=colors, labels=labels,
  #      autopct='%1.1f%%', pctdistance=0.85,
 #       explode=explode)
 
# draw circle
#centre_circle = plt.Circle((0, 0), 0.70, fc='white')
#fig = plt.gcf()
 
# Adding Circle in Pie chart
#fig.gca().add_artist(centre_circle)
 
# Adding Title of chart
#plt.title('Favourite Fruit Survey')
 
# Add Legends
#plt.legend(labels, loc="upper right", title="Fruits Color")
 
# Displaying Chart
#plt.show()
# Out:
#          Nationality  Adjusted_Earnings  count
# 0                USA        5696.520101    206
# 1            Germany         459.946363     13
# 2        Switzerland         424.943175     12
# 3           Portugal         421.360190     10
# 4          Argentina         380.440093      9
# 5                 UK         276.516927     13
# 6             Brazil         250.382961      9
# 7        Philippines         173.012356      4
# 8              Italy          80.733127      4
# 9             Canada          79.552437      6
# 10           Finland          79.314214      3
# 11           Ireland          51.512636      1
# 12            Mexico          48.040395      1
# 13            France          34.024612      3
# 14            Serbia          30.377155      1
# 15  Northern Ireland          26.651957      1
# 16             Spain          24.560235      1
# 17            Russia          23.886008      1
# 18         Dominican          20.330126      1
# ...

# %%
# Create pie charts to compare counts by sport and agregated earnings by sport
sports = adjusted_df.groupby("Sport").Adjusted_Earnings.sum().sort_values(ascending = False).reset_index()
temp = adjusted_df.Sport.value_counts(normalize=True).reset_index()
sports = pd.merge(sports.loc[:,["Sport", "Adjusted_Earnings"]], temp.loc[:,["Sport", "proportion"]], on = "Sport")
sports
# Out:
#                 Sport  Adjusted_Earnings  proportion
# 0          Basketball        2183.070245    0.272425
# 1              Boxing        1549.974067    0.152824
# 2                Golf        1359.916453    0.146179
# 3              Soccer        1212.393086    0.109635
# 4      F1 Motorsports         753.142121    0.102990
# 5              Tennis         590.798196    0.076412
# 6   American Football         549.764659    0.069767
# 7            Baseball         100.989719    0.019934
# 8              NASCAR          88.688463    0.016611
# 9       Motorcycle GP          80.733127    0.013289
# 10         Ice Hockey          62.789189    0.013289
# 11                MMA          51.512636    0.003322
# 12            Cycling          18.733177    0.003322

# %%
athlete_df.loc[athlete_df.Nationality == "Canada"]
# Out:
#                          Name Nationality  Current Rank Previous Year Rank  \
# S.NO
# 17    Donovan "Razor" Ruddock      Canada             7                >30
# 46              Wayne Gretzky      Canada             5                 22
# 60              Wayne Gretzky      Canada            10                  5
# 79                  Joe Sakic      Canada             9               none
# 120        Jacques Villeneuve      Canada            10                >10
# 131        Jacques Villeneuve      Canada            10                 10
#
#                Sport  Year  earnings ($ million)
# S.NO
# 17            Boxing  1991                  10.2
# 46        Ice Hockey  1994                  13.5
# 60        Ice Hockey  1995                  14.5
# 79        Ice Hockey  1997                  17.9
# 120   F1 Motorsports  2002                  20.0
# 131   F1 Motorsports  2003                  23.0

# %%
# Plot a graph for total adjusted earnings by sport. Stack it by US and non-US earnings.

usa_temp = adjusted_df.loc[adjusted_df.Nationality == "USA"]
usa_bysport = usa_temp.groupby("Sport").Adjusted_Earnings.sum().reset_index()
usa_bysport["region"] = "USA"

world_temp = adjusted_df.loc[adjusted_df.Nationality != "USA"]
world_bysport = world_temp.groupby("Sport").Adjusted_Earnings.sum().reset_index()
world_bysport["region"] = "World"

merged_bysport = pd.concat([usa_bysport, world_bysport])
merged_bysport

s = merged_bysport.groupby(['Sport','region']).Adjusted_Earnings.sum().unstack()

# Set graph parameters
light_color = '#F8F3E4'
dark_color = '#001219'

plt.rcParams['text.color'] = light_color
plt.rcParams['axes.labelcolor'] = light_color
plt.rcParams['xtick.color'] = light_color
plt.rcParams['ytick.color'] = light_color
plt.rcParams['axes.edgecolor'] = light_color
plt.rcParams['savefig.transparent'] = True
plt.rcParams['legend.labelcolor'] = dark_color
plt.rcParams['legend.framealpha'] = 1

# add the row wise sum for each company
s['total'] = s.sum(axis=1)

# sort
s.sort_values('total', inplace=True, ascending = True)

# plot
s[['USA', 'World']].plot(kind='barh', stacked=True, color=['#CA6702', '#94D2BD'], figsize=[15, 8])

plt.title("Aggregated adjusted earnings by sport (1990-2020)", fontweight='bold', fontname = "Calibri", fontsize = 20)
plt.xlabel("Adjusted Earnings (US$ MM)", fontname = "Calibri", fontsize = 16, fontweight = "bold")
plt.ylabel("Sports", fontname = "Calibri", fontsize = 16, fontweight = "bold")
legend = plt.legend(title = "Region")
plt.setp(legend.get_title(), color=dark_color)

plt.savefig("earnings by sport us vs world")
plt.show()

# %%
# Group by athletes
athletes = adjusted_df.groupby("Name").Adjusted_Earnings.sum().sort_values(ascending = False).reset_index()
temp = adjusted_df.Name.value_counts().reset_index()
athletes = pd.merge(athletes.loc[:,["Name", "Adjusted_Earnings"]], temp.loc[:,["Name", "count"]], on = "Name")
athletes
# Out:
#                        Name  Adjusted_Earnings  count
# 0               Tiger Woods         874.420517     19
# 1            Michael Jordan         568.121401     19
# 2              LeBron James         462.750580     13
# 3        Michael Schumacher         459.946363     13
# 4          Floyd Mayweather         458.943526      5
# ..                      ...                ...    ...
# 77            Dennis Rodman          10.745888      1
# 78           Michael Moorer          10.665986      1
# 79  Donovan "Razor" Ruddock           9.785584      1
# 80              Greg Norman           8.500000      1
# 81             Monica Seles           7.914925      1
#
# [82 rows x 3 columns]

# %%
# locate athletes to graph their incomes
athlete_df.loc[athlete_df.Sport == "Tennis"]
# Out:
#                 Name  Nationality  Current Rank Previous Year Rank   Sport  \
# S.NO
# 26      Andre Agassi          USA             6                 17  Tennis
# 29       Jim Courier          USA             9                >40  Tennis
# 30      Monica Seles          USA            10                 12  Tennis
# 39       Jim Courier          USA             9                  9  Tennis
# 49      Andre Agassi          USA             9                 20  Tennis
# 57      Andre Agassi          USA             7                  9  Tennis
# 67      Andre Agassi          USA             7                  7  Tennis
# 130     Andre Agassi          USA             9                >10  Tennis
# 138     Andre Agassi          USA             7                  9  Tennis
# 181    Roger Federer  Switzerland             9                >10  Tennis
# 197    Roger Federer  Switzerland             6                >10  Tennis
# ...

# %%
adjusted_df.loc[adjusted_df.Name == "Dale Earnhardt Jr."].sort_values(by = "Year")
# Out:
#                    Name Nationality  Current Rank Previous Year Rank   Sport  \
# 190  Dale Earnhardt Jr.         USA            10                >10  NASCAR
#
#      Year  earnings ($ million)  inflation  Adjusted_Earnings
# 190  2009                  34.0    0.64197           20.70684

# %%
nationalities.head()
nationalities_avg = adjusted_df.groupby("Nationality").Adjusted_Earnings.mean()#.sort_values(ascending = False).reset_index()
#nationalities = pd.merge(nationalities.loc[:,["Nationality", "Adjusted_Earnings"]], temp.loc[:,["Nationality", "count"]], on = "Nationality")

plt.rcParams['text.color'] = light_color
plt.rcParams['axes.labelcolor'] = light_color
plt.rcParams['xtick.color'] = light_color
plt.rcParams['ytick.color'] = light_color
plt.rcParams['axes.edgecolor'] = light_color
plt.rcParams['savefig.transparent'] = True
plt.rcParams['legend.labelcolor'] = dark_color
plt.rcParams['legend.framealpha'] = 1

nationalities_avg.sort_values(inplace=True, ascending = True)

nationalities_avg.plot(color="#94D2BD",kind="barh",stacked=True,figsize=[15,8])

plt.title("Average Adjusted Earnings By Country in Millions (USD)", fontweight='bold', fontname = "Calibri", fontsize = 20)
plt.xlabel("Adjusted Earnings", fontname = "Calibri", fontsize = 16, fontweight = "bold")
plt.ylabel("Sport", fontname = "Calibri", fontsize = 16, fontweight = "bold")
legend = plt.legend(title = "Region")
plt.setp(legend.get_title(), color=dark_color)

plt.savefig("Average Adjusted Earnigns By Country1")
plt.show()

# %%
athlete_df.Year.value_counts()
# Out:
# Year
# 2002    11
# 1990    10
# 2007    10
# 2019    10
# 2018    10
# 2017    10
# 2016    10
# 2015    10
# 2014    10
# 2013    10
# 2012    10
# 2011    10
# 2010    10
# 2009    10
# 2008    10
# 2006    10
# 1991    10
# 2005    10
# 2004    10
# 2003    10
# 2000    10
# 1999    10
# 1998    10
# 1997    10
# 1996    10
# 1995    10
# 1994    10
# 1993    10
# 1992    10
# 2020    10
# Name: count, dtype: int64

# %%
athlete_df.loc[athlete_df.Name==2002]
# Out:
# Empty DataFrame
# Columns: [Name, Nationality, Current Rank, Previous Year Rank, Sport, Year, earnings ($ million)]
# Index: []

# %%
athlete_df.loc[athlete_df.Name=="Jeff Gordon"]
# Out:
#              Name Nationality  Current Rank Previous Year Rank   Sport  Year  \
# S.NO
# 121   Jeff Gordon         USA            10                >10  NASCAR  2002
#
#       earnings ($ million)
# S.NO
# 121                   20.0

# %%
usa_temp = adjusted_df.loc[adjusted_df.Nationality == "USA"]
usa_bysport = usa_temp.groupby("Sport").Adjusted_Earnings.mean().sort_values(ascending = False).reset_index()
usa_bysport["region"] = "USA"

#world_temp = adjusted_df.loc[adjusted_df.Nationality != "USA"]
#world_bysport = world_temp.groupby("Sport").Adjusted_Earnings.sum().sort_values(ascending = False).reset_index()
#world_bysport["region"] = "World"

merged_bysport = pd.concat([usa_bysport, world_bysport])
plt.rcParams['savefig.transparent'] = True

#merged_bysport
usa_bysport.plot(title="Average earnings by Sport for the USA in Millions (USD)", x="Sport",y="Adjusted_Earnings",kind="bar",color='#CA6702')
plt.savefig("Earnings By Sport for the World in USA")
plt.show()

# %%
world_temp = adjusted_df.loc[adjusted_df.Nationality != "USA"]
world_bysport = world_temp.groupby("Sport").Adjusted_Earnings.mean().sort_values(ascending = True).reset_index()
world_bysport["region"] = "World"

plt.rcParams['savefig.transparent'] = True
plt.rcParams['legend.labelcolor'] = dark_color
#plt.rcParams['legend.framealpha'] = 1

world_bysport.plot(title="Earnings By Sport in Millions (USD)", x="Sport",y="Adjusted_Earnings",kind="barh",color="#94D2BD", figsize=[15,8])
plt.title("Average Adjusted Earnings By Sport (World) in Millions (USD)", fontweight='bold', fontname = "Calibri", fontsize = 20)
plt.xlabel("Adjusted Earnings", fontname = "Calibri", fontsize = 20, fontweight = "bold")
plt.ylabel("Sport", fontname = "Calibri", fontsize = 20, fontweight = "bold")
legend = plt.legend(title = "World")
plt.setp(legend.get_title(), color=dark_color)
plt.savefig("Average Earnings By Sport for the World in Millions")
plt.show()

# %%
adjusted_df.groupby("Sport").Sport.count().sort_values(ascending = False)
# Out:
# Sport
# Basketball           82
# Boxing               46
# Golf                 44
# Soccer               33
# F1 Motorsports       31
# Tennis               23
# American Football    21
# Baseball              6
# NASCAR                5
# Ice Hockey            4
# Motorcycle GP         4
# Cycling               1
# MMA                   1
# Name: Sport, dtype: int64

# %%
nationalities.head()
Sport_max = adjusted_df.groupby("Sport").Adjusted_Earnings.mean()#.sort_values(ascending = False).reset_index()
#nationalities = pd.merge(nationalities.loc[:,["Nationality", "Adjusted_Earnings"]], temp.loc[:,["Nationality", "count"]], on = "Nationality")

plt.rcParams['text.color'] = light_color
plt.rcParams['axes.labelcolor'] = light_color
plt.rcParams['xtick.color'] = light_color
plt.rcParams['ytick.color'] = light_color
plt.rcParams['axes.edgecolor'] = light_color
plt.rcParams['savefig.transparent'] = True
plt.rcParams['legend.labelcolor'] = dark_color
plt.rcParams['legend.framealpha'] = 1

Sport_max.sort_values(inplace=True, ascending = True)

Sport_max.plot(color="#94D2BD",kind="barh",stacked=True,figsize=[15,8])

plt.title("Average Adjusted Earnings By Sport in Millions (USD)", fontweight='bold', fontname = "Calibri", fontsize = 20)
plt.xlabel("Adjusted Earnings", fontname = "Calibri", fontsize = 16, fontweight = "bold")
plt.ylabel("Sport", fontname = "Calibri", fontsize = 16, fontweight = "bold")
legend = plt.legend(title = "Region")
plt.setp(legend.get_title(), color=dark_color)

plt.savefig("Average Adjusted Earnings By Sport")
plt.show()

# %%
world_ = adjusted_df.loc[adjusted_df.Nationality != "USA"]
world_pay = world_.groupby("Sport").Adjusted_Earnings.sum().sort_values(ascending = True).reset_index()

#world_pay

plt.rcParams['text.color'] = light_color
plt.rcParams['axes.labelcolor'] = light_color
plt.rcParams['xtick.color'] = light_color
plt.rcParams['ytick.color'] = light_color
plt.rcParams['axes.edgecolor'] = light_color
plt.rcParams['savefig.transparent'] = True
plt.rcParams['legend.labelcolor'] = dark_color
plt.rcParams['legend.framealpha'] = 1

world_pay.sort_values(inplace=True, ascending = True)

world_pay.plot(color="#94D2BD",kind="bar",stacked=True,figsize=[15,8])

plt.title("Highest Earning Sports World in Millions (USD)", fontweight='bold', fontname = "Calibri", fontsize = 20)
plt.xlabel("Sport", fontname = "Calibri", fontsize = 16, fontweight = "bold")
plt.ylabel("Adjusted Earnings", fontname = "Calibri", fontsize = 16, fontweight = "bold")
legend = plt.legend(title = "Region")
plt.setp(legend.get_title(), color=dark_color)

plt.savefig("Highest Earning Sport World")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 15
#      12 plt.rcParams['legend.labelcolor'] = dark_color
#      13 plt.rcParams['legend.framealpha'] = 1
# ---> 15 world_pay.sort_values(inplace=True, ascending = True)
#      17 world_pay.plot(color="#94D2BD",kind="bar",stacked=True,figsize=[15,8])
#      19 plt.title("Highest Earning Sports World in Millions (USD)", fontweight='bold', fontname = "Calibri", fontsize = 20)
#
# TypeError: DataFrame.sort_values() missing 1 required positional argument: 'by'

# %%
usa_ = adjusted_df.loc[adjusted_df.Nationality == "USA"]
usa_pay = usa_.groupby("Sport").Adjusted_Earnings.mean().sort_values(ascending = True).reset_index()

#usa_pay

plt.rcParams['text.color'] = light_color
plt.rcParams['axes.labelcolor'] = light_color
plt.rcParams['xtick.color'] = light_color
plt.rcParams['ytick.color'] = light_color
plt.rcParams['axes.edgecolor'] = light_color
plt.rcParams['savefig.transparent'] = True
plt.rcParams['legend.labelcolor'] = dark_color
plt.rcParams['legend.framealpha'] = 1

usa_pay.plot(title="Average Earnings By Sport in Millions, USA (USD)", x="Sport",y="Adjusted_Earnings",kind="barh",color="#CA6702", figsize=[15,8])
plt.title("Earnings By Sport in Millions, USA (USD)", fontweight='bold', fontname = "Calibri", fontsize = 20)
plt.xlabel("Adjusted Earnings", fontname = "Calibri", fontsize = 20, fontweight = "bold")
plt.ylabel("Sport", fontname = "Calibri", fontsize = 20, fontweight = "bold")
legend = plt.legend(title = "USA")
plt.setp(legend.get_title(), color=dark_color)
plt.savefig("Average Earnings By Sport USA in Millions")
plt.show()

# %%
world_temp = adjusted_df.loc[adjusted_df.Nationality != "USA"]
world_bysport = world_temp.groupby("Sport").Adjusted_Earnings.sum().sort_values(ascending = True).reset_index()
world_bysport["region"] = "World"

plt.rcParams['savefig.transparent'] = True
plt.rcParams['legend.labelcolor'] = dark_color
#plt.rcParams['legend.framealpha'] = 1

world_bysport.plot(title="Earnings By Sport in Millions (USD)", x="Sport",y="Adjusted_Earnings",kind="barh",color="#94D2BD", figsize=[15,8])
plt.title("Total Adjusted Earnings By Sport (World) in Millions (USD)", fontweight='bold', fontname = "Calibri", fontsize = 20)
plt.xlabel("Adjusted Earnings", fontname = "Calibri", fontsize = 20, fontweight = "bold")
plt.ylabel("Sport", fontname = "Calibri", fontsize = 20, fontweight = "bold")
legend = plt.legend(title = "World")
plt.setp(legend.get_title(), color=dark_color)
plt.savefig("Total Earnings By Sport for the World in Millions")
plt.show()

# %%
nationalities.head()
Sport_max = adjusted_df.groupby("Sport").Adjusted_Earnings.sum()#.sort_values(ascending = False).reset_index()
#nationalities = pd.merge(nationalities.loc[:,["Nationality", "Adjusted_Earnings"]], temp.loc[:,["Nationality", "count"]], on = "Nationality")

plt.rcParams['text.color'] = light_color
plt.rcParams['axes.labelcolor'] = light_color
plt.rcParams['xtick.color'] = light_color
plt.rcParams['ytick.color'] = light_color
plt.rcParams['axes.edgecolor'] = light_color
plt.rcParams['savefig.transparent'] = True
plt.rcParams['legend.labelcolor'] = dark_color
plt.rcParams['legend.framealpha'] = 1

Sport_max.sort_values(inplace=True, ascending = True)

Sport_max.plot(color="#94D2BD",kind="barh",stacked=True,figsize=[15,8])

plt.title("Total Adjusted Earnings By Sport in Millions (USD)", fontweight='bold', fontname = "Calibri", fontsize = 20)
plt.xlabel("Adjusted Earnings", fontname = "Calibri", fontsize = 16, fontweight = "bold")
plt.ylabel("Sport", fontname = "Calibri", fontsize = 16, fontweight = "bold")
legend = plt.legend(title = "Region")
plt.setp(legend.get_title(), color=dark_color)

plt.savefig("Total Adjusted Earnings By Sport")
plt.show()
